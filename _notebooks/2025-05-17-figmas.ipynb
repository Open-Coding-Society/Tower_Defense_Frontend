# %% [raw]
# ---
# layout: post
# title: Design Figmas for Towers and Troops
# categories: [Design]
# type: issues
# comments: true
# ---

# %% [markdown]
# ## Troops
#
# ![image.png](attachment:image.png)
#
# ## Towers
#
# ![image2.png](attachment:image2.png)
